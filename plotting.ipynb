# %%
import numpy as np
import matplotlib.pyplot as plt

lat = np.load('lat.npy')
lon = np.load('lon.npy')
band = np.load('band.npy')

plt.imshow(band, cmap='jet')  # change 'viridis' to 'jet', 'plasma', etc.
plt.colorbar(label='Reflectance')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

lat = np.load('lat1.npy')
lon = np.load('lon1.npy')
band = np.load('band1.npy')

plt.imshow(band, cmap='jet')  # change 'viridis' to 'jet', 'plasma', etc.
plt.colorbar(label='Reflectance')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

lat = np.load('lat2.npy')
lon = np.load('lon2.npy')
band = np.load('band2.npy')

plt.imshow(band, cmap='plasma')  # change 'viridis' to 'jet', 'plasma', etc.
plt.colorbar(label='Reflectance')
plt.show()
